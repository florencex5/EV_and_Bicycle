# %%
# Dependencies
import json
import requests
import pandas as pd
from api_keys import api_key_av

# %% [markdown]
# ## Querying Moving Average (20-day & 60 day)

# %%
# Set up API query for 20-day moving average of Albemarle Corporation
url = f'https://www.alphavantage.co/query?function=SMA&symbol=ALB&interval=daily&time_period=20&series_type=close&apikey={api_key_av}'
r = requests.get(url)
data = r.json()

# %%
print(data)
# Out:
# {'Meta Data': {'1: Symbol': 'ALB', '2: Indicator': 'Simple Moving Average (SMA)', '3: Last Refreshed': '2024-01-09', '4: Interval': 'daily', '5: Time Period': 20, '6: Series Type': 'close', '7: Time Zone': 'US/Eastern'}, 'Technical Analysis: SMA': {'2024-01-09': {'SMA': '142.2011'}, '2024-01-08': {'SMA': '141.8996'}, '2024-01-05': {'SMA': '141.3209'}, '2024-01-04': {'SMA': '140.4283'}, '2024-01-03': {'SMA': '139.2793'}, '2024-01-02': {'SMA': '138.2529'}, '2023-12-29': {'SMA': '137.1991'}, '2023-12-28': {'SMA': '136.0220'}, '2023-12-27': {'SMA': '134.7027'}, '2023-12-26': {'SMA': '133.4152'}, '2023-12-22': {'SMA': '131.8182'}, '2023-12-21': {'SMA': '130.7396'}, '2023-12-20': {'SMA': '129.7793'}, '2023-12-19': {'SMA': '128.9420'}, '2023-12-18': {'SMA': '127.9957'}, '2023-12-15': {'SMA': '127.0523'}, '2023-12-14': {'SMA': '125.8125'}, '2023-12-13': {'SMA': '124.8866'}, '2023-12-12': {'SMA': '124.1516'}, '2023-12-11': {'SMA': '123.4660'}, '2023-12-08': {'SMA': '122.9893'}, '2023-12-07': {'SMA': '122.3216'}, '2023-12-06': {'SMA': '122.0055'}, '2023-12-05': {'SMA': '122.1955'}, '2023-12-04': {'SMA': '122.5046'}, '2023-12-01': {'SMA': '122.9035'}, '2023-11-30': {'SMA': '122.8267'}, '2023-11-29': {'SMA': '122.9110'}, '2023-11-28': {'SMA': '123.0805'}, '2023-11-27': {'SMA': '123.2551'}, '2023-11-24': {'SMA': '123.9362'}, '2023-11-22': {'SMA': '124.2523'}, '2023-11-21': {'SMA': '124.6876'}, '2023-11-20': {'SMA': '125.3413'}, '2023-11-17': {'SMA': '125.6365'}, '2023-11-16': {'SMA': '126.1995'}, '2023-11-15': {'SMA': '127.2945'}, '2023-11-14': {'SMA': '128.5495'}, '2023-11-13': {'SMA': '130.7515'}, '2023-11-10': {'SMA': '133.4212'}, '2023-11-09': {'SMA': '135.7348'}, '2023-11-08': {'SMA': '138.5372'}, '2023-11-07': {'SMA': '140.8204'}, '2023-11-06': {'SMA': '142.8134'}, '2023-11-03': {'SMA': '144.6230'}, '2023-11-02': {'SMA': '146.2116'}, '2023-11-01': {'SMA': '147.7280'}, '2023-10-31': {'SMA': '149.4951'}, '2023-10-30': {'SMA': '150.9905'}, '2023-10-27': {'SMA': '152.7357'}, '2023-10-26': {'SMA': '154.5109'}, '2023-10-25': {'SMA': '156.3653'}, '2023-10-24': {'SMA': '157.7270'}, '2023-10-23': {'SMA': '158.9442'}, '2023-10-20': {'SMA': '160.4705'}, '2023-10-19': {'SMA': '161.9430'}, '2023-10-18': {'SMA': '163.1587'}, '2023-10-17': {'SMA': '164.2332'}, '2023-10-16': {'SMA': '164.7573'}, '2023-10-13': {'SMA': '165.4499'}, '2023-10-12': {'SMA': '166.4701'}, '2023-10-11': {'SMA': '167.1766'}, '2023-10-10': {'SMA': '168.1431'}, '2023-10-09': {'SMA': '169.2337'}, '2023-10-06': {'SMA': '170.7380'}, '2023-10-05': {'SMA': '171.9443'}, '2023-10-04': {'SMA': '173.5466'}, '2023-10-03': {'SMA': '175.0934'}, '2023-10-02': {'SMA': '177.2673'}, '2023-09-29': {'SMA': '179.1331'}, '2023-09-28': {'SMA': '180.5413'}, '2023-09-27': {'SMA': '181.8258'}, '2023-09-26': {'SMA': '183.5557'}, '2023-09-25': {'SMA': '184.8313'}, '2023-09-22': {'SMA': '185.9502'}, '2023-09-21': {'SMA': '187.0531'}, '2023-09-20': {'SMA': '188.1714'}, '2023-09-19': {'SMA': '188.8353'}, '2023-09-18': {'SMA': '189.2179'}, '2023-09-15': {'SMA': '189.2864'}, '2023-09-14': {'SMA': '189.2089'}, '2023-09-13': {'SMA': '189.0179'}, '2023-09-12': {'SMA': '188.9910'}, '2023-09-11': {'SMA': '189.0502'}, '2023-09-08': {'SMA': '189.1084'}, '2023-09-07': {'SMA': '189.4687'}, '2023-09-06': {'SMA': '189.7995'}, '2023-09-05': {'SMA': '190.0891'}, '2023-09-01': {'SMA': '189.8876'}, '2023-08-31': {'SMA': '189.8791'}, '2023-08-30': {'SMA': '189.9110'}, '2023-08-29': {'SMA': '190.1249'}, '2023-08-28': {'SMA': '190.6344'}, '2023-08-25': {'SMA': '191.7609'}, '2023-08-24': {'SMA': '192.6719'}, '2023-08-23': {'SMA': '193.4287'}, '2023-08-22': {'SMA': '194.3363'}, '2023-08-21': {'SMA': '195.5478'}, '2023-08-18': {'SMA': '196.6788'}, '2023-08-17': {'SMA': '198.3008'}, '2023-08-16': {'SMA': '200.3124'}, '2023-08-15': {'SMA': '202.8495'}, '2023-08-14': {'SMA': '205.4860'}, '2023-08-11': {'SMA': '208.0793'}, '2023-08-10': {'SMA': '210.4566'}, '2023-08-09': {'SMA': '212.9444'}, '2023-08-08': {'SMA': '215.3934'}, '2023- ...

# %%
# Convert the data into DataFrame
ALB_SMA_20ave_daily_df = pd.DataFrame(data['Technical Analysis: SMA']).T.reset_index()
ALB_SMA_20ave_daily_df.head()
# Out:
#         index       SMA
# 0  2024-01-09  142.2011
# 1  2024-01-08  141.8996
# 2  2024-01-05  141.3209
# 3  2024-01-04  140.4283
# 4  2024-01-03  139.2793

# %%
# Rename the coloumns
ALB_SMA_20ave_daily_df = ALB_SMA_20ave_daily_df.rename(columns = {'index':'Date','SMA':'SMA_20avg'})
ALB_SMA_20ave_daily_df.head()
# Out:
#          Date SMA_20avg
# 0  2024-01-09  142.2011
# 1  2024-01-08  141.8996
# 2  2024-01-05  141.3209
# 3  2024-01-04  140.4283
# 4  2024-01-03  139.2793

# %%
# Filter out data for only 2023 year
f_ALB_SMA_20ave_daily_df = ALB_SMA_20ave_daily_df[(ALB_SMA_20ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_SMA_20ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_SMA_20ave_daily_df.tail()
# Out:
#            Date SMA_20avg
# 245  2023-01-09  229.1125
# 246  2023-01-06  230.6796
# 247  2023-01-05  232.4420
# 248  2023-01-04  234.3734
# 249  2023-01-03  236.4172

# %%
# Set up API query for 60-day moving average of Albemarle Corporation
url = f'https://www.alphavantage.co/query?function=SMA&symbol=ALB&interval=daily&time_period=60&series_type=close&apikey={api_key_av}'
r = requests.get(url)
data = r.json()

# %%
# Convert the data into DataFrame
ALB_SMA_60ave_daily_df = pd.DataFrame(data['Technical Analysis: SMA']).T.reset_index()
ALB_SMA_60ave_daily_df.head()
# Out:
#         index       SMA
# 0  2024-01-09  133.6417
# 1  2024-01-08  134.2528
# 2  2024-01-05  134.7156
# 3  2024-01-04  135.1457
# 4  2024-01-03  135.4690

# %%
# Rename the coloumns
ALB_SMA_60ave_daily_df = ALB_SMA_60ave_daily_df.rename(columns = {'index':'Date','SMA':'SMA_60avg'})
ALB_SMA_60ave_daily_df.head()
# Out:
#          Date SMA_60avg
# 0  2024-01-09  133.6417
# 1  2024-01-08  134.2528
# 2  2024-01-05  134.7156
# 3  2024-01-04  135.1457
# 4  2024-01-03  135.4690

# %%
# Filter out data for only 2023 year
f_ALB_SMA_60ave_daily_df = ALB_SMA_60ave_daily_df[(ALB_SMA_60ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_SMA_60ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_SMA_60ave_daily_df.tail()
# Out:
#            Date SMA_60avg
# 245  2023-01-09  259.2077
# 246  2023-01-06  259.6545
# 247  2023-01-05  260.4957
# 248  2023-01-04  261.4713
# 249  2023-01-03  262.2730

# %% [markdown]
# ## Querying Relative Strength Index (20 day average & 60 day average)

# %%
# Set up API query for RSI of Albemarle Corporation
query_url=f'https://www.alphavantage.co/query?function=RSI&symbol=ALB&interval=daily&time_period=60&series_type=close&apikey={api_key_av}'
r = requests.get(query_url)
data = r.json()

# %%
print(data)
# Out:
# {'Meta Data': {'1: Symbol': 'ALB', '2: Indicator': 'Relative Strength Index (RSI)', '3: Last Refreshed': '2024-01-09', '4: Interval': 'daily', '5: Time Period': 60, '6: Series Type': 'close', '7: Time Zone': 'US/Eastern Time'}, 'Technical Analysis: RSI': {'2024-01-09': {'RSI': '44.8570'}, '2024-01-08': {'RSI': '45.4326'}, '2024-01-05': {'RSI': '45.2545'}, '2024-01-04': {'RSI': '45.2739'}, '2024-01-03': {'RSI': '46.0984'}, '2024-01-02': {'RSI': '47.4398'}, '2023-12-29': {'RSI': '46.8940'}, '2023-12-28': {'RSI': '47.8985'}, '2023-12-27': {'RSI': '47.8741'}, '2023-12-26': {'RSI': '48.4974'}, '2023-12-22': {'RSI': '47.9986'}, '2023-12-21': {'RSI': '46.9801'}, '2023-12-20': {'RSI': '46.3295'}, '2023-12-19': {'RSI': '47.5880'}, '2023-12-18': {'RSI': '46.9189'}, '2023-12-15': {'RSI': '47.1443'}, '2023-12-14': {'RSI': '46.8891'}, '2023-12-13': {'RSI': '45.5156'}, '2023-12-12': {'RSI': '42.6797'}, '2023-12-11': {'RSI': '42.3388'}, '2023-12-08': {'RSI': '42.5968'}, '2023-12-07': {'RSI': '41.9637'}, '2023-12-06': {'RSI': '40.2325'}, '2023-12-05': {'RSI': '38.9524'}, '2023-12-04': {'RSI': '40.0778'}, '2023-12-01': {'RSI': '41.1531'}, '2023-11-30': {'RSI': '39.8984'}, '2023-11-29': {'RSI': '40.2627'}, '2023-11-28': {'RSI': '40.3537'}, '2023-11-27': {'RSI': '39.5605'}, '2023-11-24': {'RSI': '40.9443'}, '2023-11-22': {'RSI': '40.3662'}, '2023-11-21': {'RSI': '40.2502'}, '2023-11-20': {'RSI': '40.9711'}, '2023-11-17': {'RSI': '40.2320'}, '2023-11-16': {'RSI': '39.0211'}, '2023-11-15': {'RSI': '39.8701'}, '2023-11-14': {'RSI': '39.2610'}, '2023-11-13': {'RSI': '36.3191'}, '2023-11-10': {'RSI': '36.7580'}, '2023-11-09': {'RSI': '36.1104'}, '2023-11-08': {'RSI': '36.7969'}, '2023-11-07': {'RSI': '37.2869'}, '2023-11-06': {'RSI': '36.5770'}, '2023-11-03': {'RSI': '37.9347'}, '2023-11-02': {'RSI': '37.0282'}, '2023-11-01': {'RSI': '36.5783'}, '2023-10-31': {'RSI': '37.1794'}, '2023-10-30': {'RSI': '37.2788'}, '2023-10-27': {'RSI': '38.4050'}, '2023-10-26': {'RSI': '38.5304'}, '2023-10-25': {'RSI': '38.5481'}, '2023-10-24': {'RSI': '39.1779'}, '2023-10-23': {'RSI': '38.4310'}, '2023-10-20': {'RSI': '38.8110'}, '2023-10-19': {'RSI': '39.7582'}, '2023-10-18': {'RSI': '41.1575'}, '2023-10-17': {'RSI': '44.2043'}, '2023-10-16': {'RSI': '43.7725'}, '2023-10-13': {'RSI': '42.6885'}, '2023-10-12': {'RSI': '44.1151'}, '2023-10-11': {'RSI': '42.5896'}, '2023-10-10': {'RSI': '41.8824'}, '2023-10-09': {'RSI': '40.1965'}, '2023-10-06': {'RSI': '40.9513'}, '2023-10-05': {'RSI': '39.6407'}, '2023-10-04': {'RSI': '40.2562'}, '2023-10-03': {'RSI': '39.8117'}, '2023-10-02': {'RSI': '40.8458'}, '2023-09-29': {'RSI': '42.3077'}, '2023-09-28': {'RSI': '42.7733'}, '2023-09-27': {'RSI': '40.0892'}, '2023-09-26': {'RSI': '40.2832'}, '2023-09-25': {'RSI': '40.9013'}, '2023-09-22': {'RSI': '41.1543'}, '2023-09-21': {'RSI': '41.2932'}, '2023-09-20': {'RSI': '42.3522'}, '2023-09-19': {'RSI': '43.4581'}, '2023-09-18': {'RSI': '43.7883'}, '2023-09-15': {'RSI': '44.2385'}, '2023-09-14': {'RSI': '44.4673'}, '2023-09-13': {'RSI': '44.2696'}, '2023-09-12': {'RSI': '44.2127'}, '2023-09-11': {'RSI': '44.5960'}, '2023-09-08': {'RSI': '44.1391'}, '2023-09-07': {'RSI': '44.7419'}, '2023-09-06': {'RSI': '45.1785'}, '2023-09-05': {'RSI': '47.3858'}, '2023-09-01': {'RSI': '47.2610'}, '2023-08-31': {'RSI': '46.9058'}, '2023-08-30': {'RSI': '46.8785'}, '2023-08-29': {'RSI': '46.6903'}, '2023-08-28': {'RSI': '44.8341'}, '2023-08-25': {'RSI': '44.8531'}, '2023-08-24': {'RSI': '45.0401'}, '2023-08-23': {'RSI': '45.2330'}, '2023-08-22': {'RSI': '44.4182'}, '2023-08-21': {'RSI': '44.3980'}, '2023-08-18': {'RSI': '43.3438'}, '2023-08-17': {'RSI': '43.1831'}, '2023-08-16': {'RSI': '42.9253'}, '2023-08-15': {'RSI': '43.3475'}, '2023-08-14': {'RSI': '43.5995'}, '2023-08-11': {'RSI': '43.9259'}, '2023-08-10': {'RSI': '44.6302'}, '2023-08-09': {'RSI': '45.0637'}, '2023-08-08': {'RSI': '45.3063'}, '2023-08-07': {'RSI': '45.4916'}, '2023-08-04': {'RSI': '46.0540'}, '2023-08-03': {'RSI': '45.9083'}, '202 ...

# %%
# Convert the data into DataFrame
ALB_RSI_60ave_daily_df = pd.DataFrame(data['Technical Analysis: RSI']).T.reset_index()
ALB_RSI_60ave_daily_df.head()
# Out:
#         index      RSI
# 0  2024-01-09  44.8570
# 1  2024-01-08  45.4326
# 2  2024-01-05  45.2545
# 3  2024-01-04  45.2739
# 4  2024-01-03  46.0984

# %%
# Rename the coloumns
ALB_RSI_60ave_daily_df = ALB_RSI_60ave_daily_df.rename(columns = {'index':'Date','RSI':'RSI_60'})
ALB_RSI_60ave_daily_df.head()
# Out:
#          Date   RSI_60
# 0  2024-01-09  44.8570
# 1  2024-01-08  45.4326
# 2  2024-01-05  45.2545
# 3  2024-01-04  45.2739
# 4  2024-01-03  46.0984

# %%
# Filter out data for only 2023 year
f_ALB_RSI_60ave_daily_df = ALB_RSI_60ave_daily_df[(ALB_RSI_60ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_RSI_60ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_RSI_60ave_daily_df.tail()
# Out:
#            Date   RSI_60
# 245  2023-01-09  45.8617
# 246  2023-01-06  45.5132
# 247  2023-01-05  45.0668
# 248  2023-01-04  45.6691
# 249  2023-01-03  44.3314

# %%
# Set up API query for RSI of Albemarle Corporation
query_url=f'https://www.alphavantage.co/query?function=RSI&symbol=ALB&interval=daily&time_period=20&series_type=close&apikey={api_key_av}'
r = requests.get(query_url)
data = r.json()

# %%
# Convert the data into DataFrame
ALB_RSI_20ave_daily_df = pd.DataFrame(data['Technical Analysis: RSI']).T.reset_index()
ALB_RSI_20ave_daily_df.head()
# Out:
#         index      RSI
# 0  2024-01-09  46.5605
# 1  2024-01-08  48.5411
# 2  2024-01-05  47.9995
# 3  2024-01-04  48.0636
# 4  2024-01-03  50.8016

# %%
# Rename the coloumns
ALB_RSI_20ave_daily_df = ALB_RSI_20ave_daily_df.rename(columns = {'index':'Date','RSI':'RSI_20'})
ALB_RSI_20ave_daily_df.head()
# Out:
#          Date   RSI_20
# 0  2024-01-09  46.5605
# 1  2024-01-08  48.5411
# 2  2024-01-05  47.9995
# 3  2024-01-04  48.0636
# 4  2024-01-03  50.8016

# %%
# Filter out data for only 2023 year
f_ALB_RSI_20ave_daily_df = ALB_RSI_20ave_daily_df[(ALB_RSI_20ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_RSI_20ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_RSI_20ave_daily_df.tail()
# Out:
#            Date   RSI_20
# 245  2023-01-09  39.6343
# 246  2023-01-06  38.2604
# 247  2023-01-05  36.4976
# 248  2023-01-04  38.1935
# 249  2023-01-03  32.7665

# %% [markdown]
# ## Querying Bollinger Bands (20 day average & 60 day average)

# %%
# Set up API query for RSI of Albemarle Corporation
query_url= f'https://www.alphavantage.co/query?function=BBANDS&symbol=ALB&interval=daily&time_period=20&series_type=close&nbdevup=2&nbdevdn=2&apikey={api_key_av}'
r = requests.get(query_url)
data = r.json()

# %%
print(data)
# Out:
# {'Meta Data': {'1: Symbol': 'ALB', '2: Indicator': 'Bollinger Bands (BBANDS)', '3: Last Refreshed': '2024-01-09', '4: Interval': 'daily', '5: Time Period': 20, '6.1: Deviation multiplier for upper band': 2, '6.2: Deviation multiplier for lower band': 2, '6.3: MA Type': 0, '7: Series Type': 'close', '8: Time Zone': 'US/Eastern Time'}, 'Technical Analysis: BBANDS': {'2024-01-09': {'Real Upper Band': '156.8129', 'Real Middle Band': '142.2011', 'Real Lower Band': '127.5892'}, '2024-01-08': {'Real Upper Band': '157.4235', 'Real Middle Band': '141.8996', 'Real Lower Band': '126.3756'}, '2024-01-05': {'Real Upper Band': '158.3815', 'Real Middle Band': '141.3209', 'Real Lower Band': '124.2604'}, '2024-01-04': {'Real Upper Band': '160.1979', 'Real Middle Band': '140.4283', 'Real Lower Band': '120.6586'}, '2024-01-03': {'Real Upper Band': '162.3556', 'Real Middle Band': '139.2793', 'Real Lower Band': '116.2029'}, '2024-01-02': {'Real Upper Band': '162.8534', 'Real Middle Band': '138.2529', 'Real Lower Band': '113.6523'}, '2023-12-29': {'Real Upper Band': '162.0339', 'Real Middle Band': '137.1991', 'Real Lower Band': '112.3643'}, '2023-12-28': {'Real Upper Band': '161.5858', 'Real Middle Band': '136.0220', 'Real Lower Band': '110.4583'}, '2023-12-27': {'Real Upper Band': '160.0853', 'Real Middle Band': '134.7027', 'Real Lower Band': '109.3200'}, '2023-12-26': {'Real Upper Band': '158.3090', 'Real Middle Band': '133.4152', 'Real Lower Band': '108.5215'}, '2023-12-22': {'Real Upper Band': '155.7161', 'Real Middle Band': '131.8182', 'Real Lower Band': '107.9203'}, '2023-12-21': {'Real Upper Band': '153.1419', 'Real Middle Band': '130.7396', 'Real Lower Band': '108.3373'}, '2023-12-20': {'Real Upper Band': '151.2021', 'Real Middle Band': '129.7793', 'Real Lower Band': '108.3565'}, '2023-12-19': {'Real Upper Band': '149.6014', 'Real Middle Band': '128.9420', 'Real Lower Band': '108.2827'}, '2023-12-18': {'Real Upper Band': '146.5307', 'Real Middle Band': '127.9957', 'Real Lower Band': '109.4607'}, '2023-12-15': {'Real Upper Band': '143.6651', 'Real Middle Band': '127.0523', 'Real Lower Band': '110.4395'}, '2023-12-14': {'Real Upper Band': '139.7538', 'Real Middle Band': '125.8125', 'Real Lower Band': '111.8713'}, '2023-12-13': {'Real Upper Band': '135.4125', 'Real Middle Band': '124.8866', 'Real Lower Band': '114.3607'}, '2023-12-12': {'Real Upper Band': '132.2066', 'Real Middle Band': '124.1516', 'Real Lower Band': '116.0966'}, '2023-12-11': {'Real Upper Band': '132.5075', 'Real Middle Band': '123.4660', 'Real Lower Band': '114.4245'}, '2023-12-08': {'Real Upper Band': '132.4029', 'Real Middle Band': '122.9893', 'Real Lower Band': '113.5757'}, '2023-12-07': {'Real Upper Band': '132.2036', 'Real Middle Band': '122.3216', 'Real Lower Band': '112.4396'}, '2023-12-06': {'Real Upper Band': '131.9280', 'Real Middle Band': '122.0055', 'Real Lower Band': '112.0830'}, '2023-12-05': {'Real Upper Band': '131.9462', 'Real Middle Band': '122.1955', 'Real Lower Band': '112.4448'}, '2023-12-04': {'Real Upper Band': '131.4195', 'Real Middle Band': '122.5046', 'Real Lower Band': '113.5898'}, '2023-12-01': {'Real Upper Band': '131.9845', 'Real Middle Band': '122.9035', 'Real Lower Band': '113.8225'}, '2023-11-30': {'Real Upper Band': '131.8336', 'Real Middle Band': '122.8267', 'Real Lower Band': '113.8198'}, '2023-11-29': {'Real Upper Band': '131.8771', 'Real Middle Band': '122.9110', 'Real Lower Band': '113.9449'}, '2023-11-28': {'Real Upper Band': '132.1775', 'Real Middle Band': '123.0805', 'Real Lower Band': '113.9836'}, '2023-11-27': {'Real Upper Band': '132.5154', 'Real Middle Band': '123.2551', 'Real Lower Band': '113.9947'}, '2023-11-24': {'Real Upper Band': '134.2186', 'Real Middle Band': '123.9362', 'Real Lower Band': '113.6538'}, '2023-11-22': {'Real Upper Band': '135.4286', 'Real Middle Band': '124.2523', 'Real Lower Band': '113.0760'}, '2023-11-21': {'Real Upper Band': '136.7809', 'Real Middle Band': '124.6876', 'Real Lower Band': '112.5944'}, '20 ...

# %%
# Convert the data into DataFrame
ALB_BBA_20ave_daily_df = pd.DataFrame(data['Technical Analysis: BBANDS']).T.reset_index()
ALB_BBA_20ave_daily_df.head()
# Out:
#         index Real Upper Band Real Middle Band Real Lower Band
# 0  2024-01-09        156.8129         142.2011        127.5892
# 1  2024-01-08        157.4235         141.8996        126.3756
# 2  2024-01-05        158.3815         141.3209        124.2604
# 3  2024-01-04        160.1979         140.4283        120.6586
# 4  2024-01-03        162.3556         139.2793        116.2029

# %%
# Rename the coloumns
ALB_BBA_20ave_daily_df = ALB_BBA_20ave_daily_df.rename(columns = {'index':'Date',
                                                                  'Real Upper Band':'Upper_20',
                                                                  'Real Middle Band':'Middle_20',
                                                                  'Real Lower Band':'Lower_20'})
ALB_BBA_20ave_daily_df.head()
# Out:
#          Date  Upper_20 Middle_20  Lower_20
# 0  2024-01-09  156.8129  142.2011  127.5892
# 1  2024-01-08  157.4235  141.8996  126.3756
# 2  2024-01-05  158.3815  141.3209  124.2604
# 3  2024-01-04  160.1979  140.4283  120.6586
# 4  2024-01-03  162.3556  139.2793  116.2029

# %%
# Filter out data for only 2023 year
f_ALB_BBA_20ave_daily_df = ALB_BBA_20ave_daily_df[(ALB_BBA_20ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_BBA_20ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_BBA_20ave_daily_df.tail()
# Out:
#            Date  Upper_20 Middle_20  Lower_20
# 245  2023-01-09  258.2424  229.1125  199.9826
# 246  2023-01-06  261.4589  230.6796  199.9004
# 247  2023-01-05  264.5284  232.4420  200.3555
# 248  2023-01-04  267.0958  234.3734  201.6509
# 249  2023-01-03  270.7782  236.4172  202.0562

# %%
# Set up API query for RSI of Albemarle Corporation
query_url= f'https://www.alphavantage.co/query?function=BBANDS&symbol=ALB&interval=daily&time_period=60&series_type=close&nbdevup=2&nbdevdn=2&apikey={api_key_av}'
r = requests.get(query_url)
data = r.json()

# %%
# Convert the data into DataFrame
ALB_BBA_60ave_daily_df = pd.DataFrame(data['Technical Analysis: BBANDS']).T.reset_index()
ALB_BBA_60ave_daily_df.head()
# Out:
#         index Real Upper Band Real Middle Band Real Lower Band
# 0  2024-01-09        159.8441         133.6417        107.4394
# 1  2024-01-08        162.0884         134.2528        106.4172
# 2  2024-01-05        163.5945         134.7156        105.8367
# 3  2024-01-04        164.8355         135.1457        105.4559
# 4  2024-01-03        165.6048         135.4690        105.3331

# %%
# Rename the coloumns
ALB_BBA_60ave_daily_df = ALB_BBA_60ave_daily_df.rename(columns = {'index':'Date',
                                                                  'Real Upper Band':'Upper_60',
                                                                  'Real Middle Band':'Middle_60',
                                                                  'Real Lower Band':'Lower_60'})
ALB_BBA_60ave_daily_df.head()
# Out:
#          Date  Upper_60 Middle_60  Lower_60
# 0  2024-01-09  159.8441  133.6417  107.4394
# 1  2024-01-08  162.0884  134.2528  106.4172
# 2  2024-01-05  163.5945  134.7156  105.8367
# 3  2024-01-04  164.8355  135.1457  105.4559
# 4  2024-01-03  165.6048  135.4690  105.3331

# %%
# Filter out data for only 2023 year
f_ALB_BBA_60ave_daily_df = ALB_BBA_60ave_daily_df[(ALB_BBA_60ave_daily_df['Date'] >= '2023-01') &
                                 (ALB_BBA_60ave_daily_df['Date'] <= '2024-01')].reset_index(drop=True)
f_ALB_BBA_60ave_daily_df.tail()
# Out:
#            Date  Upper_60 Middle_60  Lower_60
# 245  2023-01-09  314.1419  259.2077  204.2735
# 246  2023-01-06  313.8049  259.6545  205.5042
# 247  2023-01-05  313.7012  260.4957  207.2902
# 248  2023-01-04  313.5684  261.4713  209.3742
# 249  2023-01-03  313.3669  262.2730  211.1791

# %% [markdown]
# ## Combining all data

# %%
# Merge all dataframes
partial1_alb_df = pd.merge(f_ALB_SMA_20ave_daily_df, f_ALB_SMA_60ave_daily_df, on='Date', how='inner')
partial2_alb_df = pd.merge(partial1_alb_df, f_ALB_RSI_20ave_daily_df, on='Date', how='inner')
merged1_alb_df = pd.merge(partial2_alb_df, f_ALB_RSI_60ave_daily_df, on='Date', how='inner')
merged2_alb_df = pd.merge(merged1_alb_df, f_ALB_BBA_20ave_daily_df, on='Date', how='inner')
merged_alb_df = pd.merge(merged2_alb_df, f_ALB_BBA_60ave_daily_df, on='Date', how='inner')

merged_alb_df.head()
# Out:
#          Date SMA_20avg SMA_60avg   RSI_20   RSI_60  Upper_20 Middle_20  \
# 0  2023-12-29  137.1991  135.9179  54.0841  46.8940  162.0339  137.1991
# 1  2023-12-28  136.0220  136.1427  57.7976  47.8985  161.5858  136.0220
# 2  2023-12-27  134.7027  136.2579  57.7363  47.8741  160.0853  134.7027
# 3  2023-12-26  133.4152  136.4687  60.0474  48.4974  158.3090  133.4152
# 4  2023-12-22  131.8182  136.7551  58.8758  47.9986  155.7161  131.8182
#
#    Lower_20  Upper_60 Middle_60  Lower_60
# 0  112.3643  166.8984  135.9179  104.9374
# 1  110.4583  167.5611  136.1427  104.7244
# 2  109.3200  167.9200  136.2579  104.5958
# 3  108.5215  168.6400  136.4687  104.2973
# 4  107.9203  169.7829  136.7551  103.7273

# %%
# Sort the merged dataframe by "Date"
merged_alb_df = merged_alb_df.sort_values(by='Date').reset_index(drop=True)

merged_alb_df.head()
# Out:
#          Date SMA_20avg SMA_60avg   RSI_20   RSI_60  Upper_20 Middle_20  \
# 0  2023-01-03  236.4172  262.2730  32.7665  44.3314  270.7782  236.4172
# 1  2023-01-04  234.3734  261.4713  38.1935  45.6691  267.0958  234.3734
# 2  2023-01-05  232.4420  260.4957  36.4976  45.0668  264.5284  232.4420
# 3  2023-01-06  230.6796  259.6545  38.2604  45.5132  261.4589  230.6796
# 4  2023-01-09  229.1125  259.2077  39.6343  45.8617  258.2424  229.1125
#
#    Lower_20  Upper_60 Middle_60  Lower_60
# 0  202.0562  313.3669  262.2730  211.1791
# 1  201.6509  313.5684  261.4713  209.3742
# 2  200.3555  313.7012  260.4957  207.2902
# 3  199.9004  313.8049  259.6545  205.5042
# 4  199.9826  314.1419  259.2077  204.2735

# %%
# Write the DataFrame to a CSV file
merged_alb_df.to_csv("resource/alb_tech_indicators.csv", index=False)
